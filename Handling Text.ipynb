# %%
text1 = "Ethics and Morals are built right into the ideals and objectives of the United Nations"
len(text1)
# Out:
# 86

# %%
text2 = text1.split(" ")
len(text2)
# Out:
# 15

# %%
text3 = [w for w in text2 if len(w) > 4]
text3
# Out:
# ['Ethics',
#  'Morals',
#  'built',
#  'right',
#  'ideals',
#  'objectives',
#  'United',
#  'Nations']

# %%
text4 = [w for w in text2 if w.istitle()]
text4
# Out:
# ['Ethics', 'Morals', 'United', 'Nations']

# %%
text5 = [w for w in text2 if w.endswith('s')]
text5
# Out:
# ['Ethics', 'Morals', 'ideals', 'objectives', 'Nations']

# %%
text6 = "To be or not to be"
text7 = text6.split(" ")
len(text7)
# Out:
# 6

# %%
set([w.lower() for w in text7])
# Out:
# {'be', 'not', 'or', 'to'}

# %%
["be" in text7]
# Out:
# [True]
